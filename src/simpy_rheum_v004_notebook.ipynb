# %% [markdown]
# ### DES-Rheumatology notebook
#
# Similar to `simpy_rheum_v004_run.py` but in notebook format for easier exploration.

# %%
# %cd ..
# Out:
# c:\Users\MartinaFonseca\OneDrive - NHS England\Documents\Projects\HSMA4-12-DES-rheum

# %% [markdown]
# #### Import libraries

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
from datetime import datetime
import os
import csv
import random

import src.Batch_rheum_Model as rheum
from src.helpers import Trial_Results_initiate
from src.initialisers import g

# %% [markdown]
# #### Config and initialisation

# %%
random.seed(9001)

scriptrun_flag = True # True to save each log line by line (more efficient)
reps=2 # Number of model replications | Baseline: 30 replications
outputdir = "outputs/"
savepath = 'out_sand3/'
savepath = outputdir + savepath
start=datetime.now()
file1 = savepath + 'patient_result2.csv'
file2 = savepath + 'appt_result.csv'
file3 = savepath + 'batch_mon_audit_ls.csv'
#file4 = savepath + 'batch_kpis.csv'

# Check whether the specified output dir exists or not ##
isExist = os.path.exists(outputdir)
if not isExist:
  # Create a new directory because it does not exist 
  os.makedirs(outputdir)
  print("The new Output directory is created!")

# Check whether the specified path exists or not
isExist = os.path.exists(savepath)
if not isExist:
  # Create a new directory because it does not exist 
  os.makedirs(savepath)
  print("The new directory is created!")

Trial_Results_initiate(file1,file2,file3)

# Create a file to store trial results, and write the column headers
with open(savepath + "trial_results.csv", "w") as f:
    writer = csv.writer(f, delimiter=",")
    column_headers = ["Run", "Mean_Q_Time_FOPA",
                      "Mean_Q_Time_FUOPA",
                      "Mean_Q_Time_Total"]
    writer.writerow(column_headers)
# Out:
# The new directory is created!

# %% [markdown]
# #### Run

# %%
if scriptrun_flag:
                
    intarr = 1/6 # Inter-arrival rate (in days) | Baseline: 1/6 days, i.e. 6 per day
    in_path_horizon_y=3 # Patient follow-up horizon, simplification on how long each non first-only pathway lasts (years) | Baseline: 3
    
    #in_prob_pifu = 0
    in_prob_pifu = 0.2 # PIFU proportion - probability of PIFU pathway for non first-only pathways | Baseline: 0 | Scenarios: 0.1,0.2,0.3,0.5
    
    in_FOavoidable = 0 # A&G proportion - proportion of first-only pathways avoidable via A&G | Baseline: 0 | Scenario: 0.43
    #in_FOavoidable = 0.43
    
    in_interfu_perc = 0.6 # Percentage increase in inter-appointment interval with PIFU (vs traditional), i.e. 0.6 means 60% longer interval | Baseline: 0.6 | Scenarios: 0.6, 0.2
    #in_interfu_perc = 0.2 # More conservative. Used in scenario C
    
    g_defaults = g()
    audit_interval = 28 # audit timepoint (in simulation days)
    
    cap  = 1/intarr * ((2 + in_path_horizon_y / g_defaults.mean_interOPA *365) * (1-g_defaults.prob_firstonly) + 2 * g_defaults.prob_firstonly)# * Heuristic of daily slots (365 days) needed to deal with steady-state model demand
    cap_diff = 0 # Increment or decrement in daily slots to be applied to the heuristic | Baseline: 0
    
    # Set up constructor instance
    my_batch_model = rheum.Batch_rheum_model(in_res=np.round(cap,0) + cap_diff,
                                             in_inter_arrival=intarr,
                                             in_prob_pifu=in_prob_pifu,
                                             in_path_horizon_y=in_path_horizon_y,
                                             audit_interval=audit_interval,
                                             in_savepath = savepath,
                                             in_FOavoidable = in_FOavoidable,
                                             in_interfu_perc=in_interfu_perc)
    
    # Run model
    fig_audit_reps, chart_output_lastrep, text_output_lastrep, quant_output_lastrep, fig_q_audit_reps,fig_monappKPI_reps, fig_monappKPIn_reps = my_batch_model.run_reps(reps=reps)

    endtime = datetime.now()
# Out:
# Run 1 of 2
#
# -- Audit Day 1825
# --- Patients waiting: First: 375, PIFU: 0, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 1853
# --- Patients waiting: First: 372, PIFU: 0, Traditional: 2
# --- Slots used: 43
# --
#
# -- Audit Day 1881
# --- Patients waiting: First: 372, PIFU: 0, Traditional: 9
# --- Slots used: 43
# --
#
# -- Audit Day 1909
# --- Patients waiting: First: 361, PIFU: 0, Traditional: 7
# --- Slots used: 43
# --
#
# -- Audit Day 1937
# --- Patients waiting: First: 390, PIFU: 0, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 1965
# --- Patients waiting: First: 428, PIFU: 0, Traditional: 12
# --- Slots used: 43
# --
#
# -- Audit Day 1993
# --- Patients waiting: First: 452, PIFU: 0, Traditional: 2
# --- Slots used: 43
# --
#
# -- Audit Day 2021
# --- Patients waiting: First: 438, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2049
# --- Patients waiting: First: 443, PIFU: 2, Traditional: 7
# --- Slots used: 43
# --
#
# -- Audit Day 2077
# --- Patients waiting: First: 463, PIFU: 2, Traditional: 3
# --- Slots used: 43
# --
#
# -- Audit Day 2105
# --- Patients waiting: First: 481, PIFU: 3, Traditional: 12
# --- Slots used: 43
# --
#
# -- Audit Day 2133
# --- Patients waiting: First: 489, PIFU: 0, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2161
# --- Patients waiting: First: 476, PIFU: 1, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2189
# --- Patients waiting: First: 442, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2217
# --- Patients waiting: First: 483, PIFU: 4, Traditional: 7
# --- Slots used: 43
# --
#
# -- Audit Day 2245
# --- Patients waiting: First: 473, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2273
# --- Patients waiting: First: 469, PIFU: 0, Traditional: 8
# --- Slots used: 43
# --
#
# -- Audit Day 2301
# --- Patients waiting: First: 467, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2329
# --- Patients waiting: First: 481, PIFU: 2, Traditional: 9
# --- Slots used: 43
# --
#
# -- Audit Day 2357
# --- Patients waiting: First: 457, PIFU: 0, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2385
# --- Patients waiting: First: 454, PIFU: 1, Traditional: 19
# --- Slots used: 43
# --
#
# -- Audit Day 2413
# --- Patients waiting: First: 447, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2441
# --- Patients waiting: First: 421, PIFU: 4, Traditional: 6
# --- Slots used: 43
# --
#
# -- Audit Day 2469
# --- Patients waiting: First: 410, PIFU: 2, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2497
# --- Patients waiting: First: 408, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2525
# --- Patients waiting: First: 445, PIFU: 1, Traditional: 4
# --- Slots used: 43
# --
#
# -- Audit Day 2553
# --- Patients waiting: First: 436, PIFU: 1, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2581
# --- Patients waiting: First: 438, PIFU: 3, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2609
# --- Patients waiting: First: 457, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2637
# --- Patients waiting: First: 459, PIFU: 1, Traditional: 3
# --- Slots used: 43
# --
#
# -- Audit Day 2665
# --- Patients waiting: First: 493, PIFU: 1, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2693
# --- Patients waiting: First: 496, PIFU: 0, Traditional: 3
# --- Slots used: 43
# --
#
# -- Audit Day 2721
# --- Patients waiting: First: 506, PIFU: 1, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2749
# --- Patients waiting: First: 479, PIFU: 2, Traditional: 5
# --- Slots used: 43
# --
#
# -- Audit Day 2777
# --- Patients waiting: First: 479, PIFU: 4, Traditional: 9
# --- Slots used: 43
# --
#
# -- Audit Day 2805
# --- Patients waiting: First: 501, PIFU: 2, Traditional: 3
# --- Slots used: 43
# --
#
# -- Audit Day 2833
# --- Patients waiting: First: 521, PIFU: 2, Traditional: 7
# --- Slots used: 43
# --
#
# -- Audit Day 2861
# --- Patients waiting: First: 511, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2889
# --- Patients waiting: First: 494, PIFU: 2, Traditional: 6
# --- Slots used: 43
# --
#
# -- Audit Day 2917
# --- Patients waiting: First: 502, PIFU: 2, Traditional: 0
# --- Slots used: 43
# --
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [0, 75.20356202061812, 999.0, 15121.703562020619]
# c:\Users\MartinaFonseca\OneDrive - NHS England\Documents\Projects\HSMA4-12-DES-rheum\src\rheum_Model.py:508: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax32.set_xticklabels(ax32.get_xticklabels(),rotation = 30)
# Run-time of Run 1: 0:01:46.961205
#
# Run 2 of 2
#
# -- Audit Day 1825
# --- Patients waiting: First: 435, PIFU: 0, Traditional: 8
# --- Slots used: 43
# --
#
# -- Audit Day 1853
# --- Patients waiting: First: 440, PIFU: 0, Traditional: 6
# --- Slots used: 43
# --
#
# -- Audit Day 1881
# --- Patients waiting: First: 417, PIFU: 0, Traditional: 5
# --- Slots used: 43
# --
#
# -- Audit Day 1909
# --- Patients waiting: First: 453, PIFU: 0, Traditional: 2
# --- Slots used: 43
# --
#
# -- Audit Day 1937
# --- Patients waiting: First: 448, PIFU: 0, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 1965
# --- Patients waiting: First: 494, PIFU: 0, Traditional: 9
# --- Slots used: 43
# --
#
# -- Audit Day 1993
# --- Patients waiting: First: 500, PIFU: 0, Traditional: 4
# --- Slots used: 43
# --
#
# -- Audit Day 2021
# --- Patients waiting: First: 496, PIFU: 0, Traditional: 8
# --- Slots used: 43
# --
#
# -- Audit Day 2049
# --- Patients waiting: First: 499, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2077
# --- Patients waiting: First: 516, PIFU: 0, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2105
# --- Patients waiting: First: 513, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2133
# --- Patients waiting: First: 531, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2161
# --- Patients waiting: First: 545, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2189
# --- Patients waiting: First: 560, PIFU: 0, Traditional: 4
# --- Slots used: 43
# --
#
# -- Audit Day 2217
# --- Patients waiting: First: 588, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2245
# --- Patients waiting: First: 578, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2273
# --- Patients waiting: First: 583, PIFU: 0, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2301
# --- Patients waiting: First: 604, PIFU: 2, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2329
# --- Patients waiting: First: 584, PIFU: 0, Traditional: 8
# --- Slots used: 43
# --
#
# -- Audit Day 2357
# --- Patients waiting: First: 573, PIFU: 2, Traditional: 10
# --- Slots used: 43
# --
#
# -- Audit Day 2385
# --- Patients waiting: First: 571, PIFU: 4, Traditional: 3
# --- Slots used: 43
# --
#
# -- Audit Day 2413
# --- Patients waiting: First: 529, PIFU: 2, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2441
# --- Patients waiting: First: 512, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2469
# --- Patients waiting: First: 484, PIFU: 0, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2497
# --- Patients waiting: First: 488, PIFU: 2, Traditional: 2
# --- Slots used: 43
# --
#
# -- Audit Day 2525
# --- Patients waiting: First: 482, PIFU: 0, Traditional: 3
# --- Slots used: 43
# --
#
# -- Audit Day 2553
# --- Patients waiting: First: 472, PIFU: 4, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2581
# --- Patients waiting: First: 444, PIFU: 3, Traditional: 3
# --- Slots used: 43
# --
#
# -- Audit Day 2609
# --- Patients waiting: First: 446, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2637
# --- Patients waiting: First: 451, PIFU: 1, Traditional: 10
# --- Slots used: 43
# --
#
# -- Audit Day 2665
# --- Patients waiting: First: 431, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2693
# --- Patients waiting: First: 393, PIFU: 3, Traditional: 5
# --- Slots used: 43
# --
#
# -- Audit Day 2721
# --- Patients waiting: First: 398, PIFU: 1, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2749
# --- Patients waiting: First: 405, PIFU: 1, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2777
# --- Patients waiting: First: 420, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2805
# --- Patients waiting: First: 410, PIFU: 0, Traditional: 1
# --- Slots used: 43
# --
#
# -- Audit Day 2833
# --- Patients waiting: First: 369, PIFU: 0, Traditional: 2
# --- Slots used: 43
# --
#
# -- Audit Day 2861
# --- Patients waiting: First: 376, PIFU: 1, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2889
# --- Patients waiting: First: 405, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
#
# -- Audit Day 2917
# --- Patients waiting: First: 370, PIFU: 0, Traditional: 0
# --- Slots used: 43
# --
# [1, 78.33107863155897, 999.0, 15156.042860123609]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\Users\MartinaFonseca\OneDrive - NHS England\Documents\Projects\HSMA4-12-DES-rheum\src\rheum_Model.py:508: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax32.set_xticklabels(ax32.get_xticklabels(),rotation = 30)
# Run-time of Run 2: 0:01:54.418564
# c:\Users\MartinaFonseca\OneDrive - NHS England\Documents\Projects\HSMA4-12-DES-rheum\src\Batch_rheum_Model.py:85: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# c:\Users\MartinaFonseca\OneDrive - NHS England\Documents\Projects\HSMA4-12-DES-rheum\src\Batch_rheum_Model.py:85: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# c:\Users\MartinaFonseca\OneDrive - NHS England\Documents\Projects\HSMA4-12-DES-rheum\src\Batch_rheum_Model.py:85: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# c:\Users\MartinaFonseca\OneDrive - NHS England\Documents\Projects\HSMA4-12-DES-rheum\src\Batch_rheum_Model.py:85: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# c:\Users\MartinaFonseca\OneDrive - NHS England\Documents\Projects\HSMA4-12-DES-rheum\src\Batch_rheum_Model.py:184: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 80)
# c:\Users\MartinaFonseca\OneDrive - NHS England\Documents\Projects\HSMA4-12-DES-rheum\src\Batch_rheum_Model.py:184: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 80)

# %% [markdown]
# #### Outputs

# %%
# =============================================================================  
    
# Some output KPIs generated and printed
#my_batch_model.headline_KPI(365)    
#mydf = my_batch_model.headline_KPI(365)    
#my_batch_model.save_logs()           
print(my_batch_model.batch_kpi)

# Model performance - time       
scenario2run = endtime-start
print(f"Overall run-time of {scenario2run}")
# Out:
#                        KPI_mean      KPI_LCI      KPI_UCI
# KPI
# RTT_WL_end           436.000000  -402.609513  1274.609513
# RTT_mean              77.037729    -2.248000   156.323458
# RTT_n               1673.000000  1520.525543  1825.474457
# RTT_q0.5              77.130337    -6.534523   160.795198
# RTT_q0.75             79.530568    -8.268778   167.329914
# RTT_q0.92             81.727737    -1.477850   164.933325
# RTT_q0.95             82.740400     7.512106   157.968694
# resources occupied    43.000000    43.000000    43.000000
# Overall run-time of 0:05:55.842101
